# %%
import cv2

# %%
import numpy as np

# %%
input = cv2.imread(r"C:\Users\Saloni\Desktop\eagle.webp")

# %%
input
# Out:
# array([[[ 16,  41,  27],
#         [ 16,  41,  27],
#         [ 16,  41,  27],
#         ...,
#         [ 20,  25,  24],
#         [ 20,  25,  24],
#         [ 20,  25,  24]],
#
#        [[ 16,  41,  27],
#         [ 16,  41,  27],
#         [ 16,  41,  27],
#         ...,
#         [ 20,  25,  24],
#         [ 20,  25,  24],
#         [ 20,  25,  24]],
#
#        [[ 16,  41,  27],
#         [ 16,  41,  27],
#         [ 16,  41,  27],
#         ...,
#         [ 22,  26,  26],
#         [ 22,  26,  26],
#         [ 22,  26,  26]],
#
#        ...,
#
#        [[ 73, 123, 144],
#         [ 73, 123, 144],
#         [ 73, 123, 144],
#         ...,
#         [ 79, 121, 146],
#         [ 79, 121, 146],
#         [ 79, 121, 146]],
#
#        [[ 75, 125, 147],
#         [ 75, 125, 147],
#         [ 75, 125, 147],
#         ...,
#         [ 79, 121, 146],
#         [ 79, 121, 146],
#         [ 79, 121, 146]],
#
#        [[ 78, 127, 149],
#         [ 78, 127, 149],
#         [ 78, 127, 149],
#         ...,
#         [ 79, 121, 146],
#         [ 79, 121, 146],
#         [ 79, 121, 146]]], dtype=uint8)

# %%
cv2.imshow('eagle',input)

cv2.waitKey(3000)

cv2.destroyAllWindows()

# %%
print('Height of Image:',int(input.shape[0]),'pixels')
print('Width of Image:',int(input.shape[1]),'pixels')
# Out:
# Height of Image: 533 pixels
# Width of Image: 800 pixels

# %%
cv2.imwrite('output.png',input)
# Out:
# True

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\Saloni\\Downloads\\Data Science\\vs code\\OpenCV\\Basic code'
